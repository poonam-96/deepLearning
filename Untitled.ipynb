# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.image as img
from glob import glob

from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
dog_names = [item[20:-1] for item in sorted(glob("labels.csv"))]
print('There are %d total dog categories.' % len(dog_names))
# Out:
# There are 1 total dog categories.

# %%
ax=pd.value_counts(df['breed'],ascending=True).plot(kind='barh',
                                                       fontsize="40",
                                                       title="Class Distribution",
                                                       figsize=(50,100))
ax.set(xlabel="Images per class", ylabel="Classes")
ax.xaxis.label.set_size(40)
ax.yaxis.label.set_size(40)
ax.title.set_size(60)

# %%
files = df.id.tolist()

# %%
ls = []
for item in files:
    ls.append('train/' + item + '.jpg')

# %%
import time

# %%
t = time.time()
features = []
for i, im_path in enumerate(ls):
    img = cv2.imread(im_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (299,299)) 
    img = img/255.0
    img = img.reshape(1,299, 299, 3)
    out = model.predict(img)
    features.append(out)
    if i%100==0:
        print(i)
#         break


features = np.squeeze(features)

np.save('./Documents/nisar/dog breed/featurs.npy', features)
time.time() - t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5f7f7c3f14b9> in <module>
#       7     img = img/255.0
#       8     img = img.reshape(1,299, 299, 3)
# ----> 9     out = model.predict(img)
#      10     features.append(out)
#      11     if i%100==0:
#
# NameError: name 'model' is not defined
